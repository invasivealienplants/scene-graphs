# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import scipy.misc as misc
import json
import urllib.request
import h5py
from graphviz import Digraph

# %%
import os
os.environ["PATH"] += os.pathsep + 'C:/Program Files (x86)/Graphviz2.38/bin/'
# or path to graphviz on pc
# installing with conda should create this path

# %%
import utils

# %%
coco_image_data = utils.get_image_data()
objects = utils.get_object_types()
predicates = utils.get_predicate_types()

# %%
scene_graphs = h5py.File('exp/sg_results/coco_scenegraphs_px2graph.h5','r')

# %%
info = (coco_image_data,scene_graphs,objects,predicates)

# %%
objs,rels = utils.get_graph_matrix(6,info,object_threshold=0.3,only_connected=True,nonmax_suppress=0.7)

# %%
print(objs.shape,rels.shape)
# Out:
# (11, 7) (12, 4)

# %%
g = utils.visualize(6,info,object_threshold=0.3,only_connected=True,nonmax_suppress=0.7)
g.view()
# Out:
# 'Digraph.gv.pdf'
